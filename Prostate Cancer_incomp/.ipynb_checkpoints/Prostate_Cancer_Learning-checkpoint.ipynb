# %% [markdown]
# # Predicting whether a person has Prostate Cancer

# %% [markdown]
# ## Importing and Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("Prostate_Cancer.csv")
df.drop(columns=['id'], inplace=True)
df
# Out:
#    diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0                 M      23       12        151   954       0.143
# 1                 B       9       13        133  1326       0.143
# 2                 M      21       27        130  1203       0.125
# 3                 M      14       16         78   386       0.070
# 4                 M       9       19        135  1297       0.141
# ..              ...     ...      ...        ...   ...         ...
# 95                M      23       16        132  1264       0.091
# 96                B      22       14         78   451       0.105
# 97                B      19       27         62   295       0.102
# 98                B      21       24         74   413       0.090
# 99                M      16       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# 1         0.079     0.181              0.057
# ...

# %% [markdown]
# ## Exploratory data analysis

# %%
df.isnull().sum()
# Out:
# diagnosis_result     0
# radius               0
# texture              0
# perimeter            0
# area                 0
# smoothness           0
# compactness          0
# symmetry             0
# fractal_dimension    0
# dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Feature Engineering

# %%
def diag_imputing(col):
    if col == 'M':
        return 0
    elif col == 'B':
        return 1
    else:
        return col
    
df['diagnosis_result'] = df['diagnosis_result'].apply(diag_imputing)
df
# Out:
#     diagnosis_result  radius  texture  perimeter  area  smoothness  \
# 0                  0      23       12        151   954       0.143
# 1                  1       9       13        133  1326       0.143
# 2                  0      21       27        130  1203       0.125
# 3                  0      14       16         78   386       0.070
# 4                  0       9       19        135  1297       0.141
# ..               ...     ...      ...        ...   ...         ...
# 95                 0      23       16        132  1264       0.091
# 96                 1      22       14         78   451       0.105
# 97                 1      19       27         62   295       0.102
# 98                 1      21       24         74   413       0.090
# 99                 0      16       27         94   643       0.098
#
#     compactness  symmetry  fractal_dimension
# 0         0.278     0.242              0.079
# 1         0.079     0.181              0.057
# ...

# %%
x_col = df.drop(columns=['diagnosis_result'])
y_col = df['diagnosis_result']
mms = MinMaxScaler()
x_norm = mms.fit_transform(x_col)

# %% [markdown]
# ## Training, Prediction and Evaluation

# %% [markdown]
# ### Predicting without normalisation

# %%
x_train, x_test, y_train, y_test = train_test_split(x_col, y_col, random_state=0)

# %%
knnc = KNeighborsClassifier(n_neighbors=11)
knnc.fit(x_train,y_train)
prd = knnc.predict(x_test)

# %%
print(classification_report(y_test, prd))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89        21
#            1       0.50      1.00      0.67         4
#
#     accuracy                           0.84        25
#    macro avg       0.75      0.90      0.78        25
# weighted avg       0.92      0.84      0.86        25

# %% [markdown]
# ### Predicting normalised values

# %%
x_train_n, x_test_n, y_train_n, y_test_n = train_test_split(x_norm, y_col, random_state=0)

# %%
knnc = KNeighborsClassifier(n_neighbors=11)
knnc.fit(x_train_n,y_train_n)
prd = knnc.predict(x_test_n)

# %%
print(classification_report(y_test_n, prd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87        21
#            1       0.43      0.75      0.55         4
#
#     accuracy                           0.80        25
#    macro avg       0.69      0.78      0.71        25
# weighted avg       0.86      0.80      0.82        25
